# %%
import pandas as pd

# %%
recipe_vec = pd.read_pickle("data/processed/recipe_vectors.pickle")

# %%
recipe_vec.head()
# Out:
#                                                               \
# http://www.epicurious.com/recipes/food/views/-a...   0.00000
# http://www.epicurious.com/recipes/food/views/-a...   0.00000
# http://www.epicurious.com/recipes/food/views/-b...  14.78680
# http://www.epicurious.com/recipes/food/views/-b...  39.43146
# http://www.epicurious.com/recipes/food/views/-b...   0.00000
#
#                                                     (about tomatillo  \
# http://www.epicurious.com/recipes/food/views/-a...               0.0
# http://www.epicurious.com/recipes/food/views/-a...               0.0
# http://www.epicurious.com/recipes/food/views/-b...               0.0
# http://www.epicurious.com/recipes/food/views/-b...               0.0
# http://www.epicurious.com/recipes/food/views/-b...               0.0
#
#                                                     (almond tablespoon flour  \
# http://www.epicurious.com/recipes/food/views/-a...                       0.0
# ...

# %%
from sklearn.cluster import DBSCAN
