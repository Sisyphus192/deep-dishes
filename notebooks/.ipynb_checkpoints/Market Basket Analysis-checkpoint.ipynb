# %%
import pandas as pd
import numpy as np
import uuid
from collections import Counter
import math
from progressbar import ProgressBar, AdaptiveETA, Percentage, Bar, RotatingMarker

# %%
df = pd.read_hdf('../data/processed/epi_vector.h5')

# %%
dat = df.values[:,:-8]

# %%
columns = list(df)
new_vec = []
for recipe in dat:
    ind = uuid.uuid4().hex
    for i in range(len(recipe)):
        if recipe[i] != 0:
            new_vec.append([ind, columns[i]])

# %%
print(len(dat))
basketized = pd.DataFrame(new_vec, columns=["index", "name"]).set_index('index', drop=False)
del basketized["index"]
basketized.head()
# Out:
# 34626
#                                                            name
# index
# a54b174876bc4e80b58f4c93662cf6ce  coarsely grated sharp Cheddar
# a54b174876bc4e80b58f4c93662cf6ce                   garlic clove
# 70214f9b407f433780fa0f973342e477                         almond
# 70214f9b407f433780fa0f973342e477                    apricot jam
# 70214f9b407f433780fa0f973342e477                         brandy

# %%
def generate_candidate_set(size, L):
    candidate_set = set()
    for i in range(len(L)):
        for j in range(i+1, len(L)):
            diff = L[i].difference(L[j])
            if len(diff) == 1:
                candidate_set.add(frozenset.union(L[i], L[j]))
    return candidate_set

def apriori(frame, support_per):
    candidate_sets = []
    frequent_sets = []
    thresh = math.floor(len(frame.groupby(level=0))*support_per)
    
    C1 = Counter()
    for ind, basket in frame.groupby(level=0):
        for item in basket.values:
            C1[item[0]] += 1
    
    L1 = []
    for item in C1.most_common():
        if item[1] > thresh:
            L1.append(set([item[0]]))
    print(L1)
    
    count = Counter()
    candidate = generate_candidate_set(2, L1)
    frequent = []
    size = 2
    while len(candidate) != 0:
        widgets = ['Counting C{}: '.format(size), Percentage(), ' ', Bar(marker=RotatingMarker()), ' ', AdaptiveETA()]
        pbar = ProgressBar(widgets=widgets)
        for ind, basket in pbar(frame.groupby(level=0)):
            for c in candidate:
                if basket["name"].isin(c).sum() == len(c):
                    count[c] += 1
        for item in count.most_common():
            if item[1] > thresh:
                frequent.append(set([item[0]]))
        candidate_sets.append(candidate)
        frequent_sets.append(frequent)
        size += 1
        count = Counter()
        candidate = generate_candidate_set(size, frequent)
        frequent = []
        
    return candidate_sets, frequent_sets

def apriori_quick(frame, vec_frame, support_per):
    candidate_sets = []
    frequent_sets = []
    thresh = math.floor(len(frame.groupby(level=0))*support_per)
    ing_map = {}
    dat = vec_frame.values
    columns = list(vec_frame)
    for i in range(len(columns)-8):
        ing_map[columns[i]] = i
    
    C1 = Counter()
    for ind, basket in frame.groupby(level=0):
        for item in basket.values:
            C1[item[0]] += 1
    
    L1 = []
    for item in C1.most_common():
        if item[1] > thresh:
            L1.append(frozenset([item[0]]))
    print(L1)
    
    count = Counter()
    candidate = generate_candidate_set(2, L1)
    frequent = []
    size = 2
    while len(candidate) != 0:
        widgets = ['Counting C{}: '.format(size), Percentage(), ' ', Bar(marker=RotatingMarker()), ' ', AdaptiveETA()]
        pbar = ProgressBar(widgets=widgets)
        for c in pbar(candidate):
            check_vec = []
            for ing in c:
                check_vec.append(ing_map[ing])
            for recipe in dat:
                if np.count_nonzero(recipe[check_vec]) == len(check_vec):
                    count[c] += 1
        for item in count.most_common():
            if item[1] > thresh:
                frequent.append(item[0])
        candidate_sets.append(candidate)
        frequent_sets.append(frequent)
        size += 1
        count = Counter()
        candidate = generate_candidate_set(size, frequent)
        frequent = []
        
    return candidate_sets, frequent_sets

# %%
c_sets, f_sets = apriori_quick(basketized, df, 0.01)
# Out:
# Counting C2:   0% |                                            | ETA:  --:--:--
# [frozenset({'salt'}), frozenset({'olive oil'}), frozenset({'sugar'}), frozenset({'egg'}), frozenset({'garlic'}), frozenset({'unsalted butter'}), frozenset({'onion'}), frozenset({'water'}), frozenset({'lemon juice'}), frozenset({'black pepper'}), frozenset({'all - purpose flour'}), frozenset({'vegetable oil'}), frozenset({'unsalte butter'}), frozenset({'milk'}), frozenset({'butter'}), frozenset({'vanilla extract'}), frozenset({'ginger'}), frozenset({'shallot'}), frozenset({'chicken broth'}), frozenset({'garlic clove'}), frozenset({'cinnamon'}), frozenset({'thyme'}), frozenset({'carrot'}), frozenset({'baking powder'}), frozenset({'lime juice'}), frozenset({'tomato'}), frozenset({'all purpose flour'}), frozenset({'parsley'}), frozenset({'heavy cream'}), frozenset({'whip cream'}), frozenset({'red onion'}), frozenset({'cilantro'}), frozenset({'dry white wine'}), frozenset({'cumin'}), frozenset({'baking soda'}), frozenset({'potato'}), frozenset({'honey'}), frozenset({'scallion'}), frozenset({'Dijon mustard'}), frozenset({'kosher salt'}), frozenset({'red bell pepper'}), frozenset({'soy sauce'}), frozenset({'lemon'}), frozenset({'rosemary'}), frozenset({'green onion'}), frozenset({'celery'}), frozenset({'oregano'}), frozenset({'extra - virgin olive oil'}), frozenset({'cornstarch'}), frozenset({'orange juice'}), frozenset({'mayonnaise'}), frozenset({'chive'}), frozenset({'lemon peel'}), frozenset({'basil'}), frozenset({'sour cream'}), frozenset({'almond'}), frozenset({'lemon zest'}), frozenset({'shrimp'}), frozenset({'bacon'}), frozenset({'parsley leave'}), frozenset({'balsamic vinegar'}), frozenset({'nutmeg'}), frozenset({'parmesan cheese'}), frozenset({'clove'}), frozenset({'walnut'}), frozenset({'golden brown sugar'}), frozenset({'buttermilk'}), frozenset({'chocolate'}), frozenset({'brown sugar'}), frozenset({'vanilla'}), frozenset({'ice cube'}), frozenset({'red wine vinegar'}), frozenset({'mushroom'}), frozenset({'red pepper flake'}), frozenset({'mint'}), frozenset({'leek'}), frozenset({'black peppercorn'}), frozenset({'bay leave'}), frozenset({'plum tomato'}), frozenset({'orange peel'}), frozenset({'caper'}), frozenset({'basil leave'}), frozenset({'dill'}), frozenset({'zucchini'}), frozenset({'red pepper'}), frozenset({'mint leave'}), frozenset({'bay leaf'}), frozenset({'apple'}), frozenset({'allspice'}), frozenset({'vanilla bean'}), frozenset({'coriander'}), frozenset({'dark brown sugar'}), frozenset({'cayenne pepper'}), frozenset({'pecan'}), frozenset({'orange'}), frozenset({'light brown sugar'}), frozenset({'tomato paste'}), frozenset({'strawberry'}), frozenset({'rice vinegar'}), frozenset({'cucumber'}), frozenset({'paprika'}), frozenset({'tarragon'}), frozenset({'Worcestershire sauce'}), frozenset({'italian parsley'}), frozenset({'corn syrup'}), frozenset({'fennel seed'}), frozenset({'sage'}), frozenset({'coarse kosher salt'}), frozenset({'white wine vinegar'}), frozenset({'green bell pepper'}), frozenset({'fennel bulb'}), frozenset({'coriander seed'}), frozenset({'cumin seed'}), frozenset({'chicken breast'}), frozenset({'sesame oil'}), frozenset({'avocado'}), frozenset({'cider vinegar'}), frozenset({'chili powder'}), frozenset({'cream cheese'}), frozenset({'curry powder'}), frozenset({'celery rib'}), frozenset({'sesame seed'}), frozenset({'dry red wine'}), frozenset({'maple syrup'}), frozenset({'pine nut'}), frozenset({'cranberry'}), frozenset({'cocoa powder'}), frozenset({'turmeric'}), frozenset({'brandy'}), frozenset({'chicken'}), frozenset({'gin'}), frozenset({'cherry tomato'}), frozenset({'lime'}), frozenset({'apple cider vinegar'}), frozenset({'heavy whip cream'})]
# Counting C2: 100% ||||||||||||||||||||||||||||||||||||||||||||||| Time: 0:13:43
# Counting C3: 100% ||||||||||||||||||||||||||||||||||||||||||||||| Time: 0:04:59
# Counting C4: 100% ||||||||||||||||||||||||||||||||||||||||||||||| Time: 0:00:55
# Counting C5: 100% ||||||||||||||||||||||||||||||||||||||||||||||| Time: 0:00:11
# Counting C6: 100% ||||||||||||||||||||||||||||||||||||||||||||||| Time: 0:00:00

# %%
for f in f_sets:
    print(f)
# Out:
# [frozenset({'salt', 'egg'}), frozenset({'sugar', 'egg'}), frozenset({'garlic', 'olive oil'}), frozenset({'salt', 'sugar'}), frozenset({'egg', 'unsalted butter'}), frozenset({'salt', 'unsalted butter'}), frozenset({'sugar', 'unsalted butter'}), frozenset({'onion', 'garlic'}), frozenset({'onion', 'olive oil'}), frozenset({'salt', 'black pepper'}), frozenset({'salt', 'olive oil'}), frozenset({'salt', 'water'}), frozenset({'sugar', 'water'}), frozenset({'salt', 'all - purpose flour'}), frozenset({'egg', 'all - purpose flour'}), frozenset({'egg', 'vanilla extract'}), frozenset({'salt', 'garlic'}), frozenset({'sugar', 'vanilla extract'}), frozenset({'egg', 'milk'}), frozenset({'lemon juice', 'olive oil'}), frozenset({'egg', 'baking powder'}), frozenset({'salt', 'onion'}), frozenset({'salt', 'baking powder'}), frozenset({'unsalted butter', 'all - purpose flour'}), frozenset({'sugar', 'all - purpose flour'}), frozenset({'unsalted butter', 'vanilla extract'}), frozenset({'black pepper', 'olive oil'}), frozenset({'salt', 'vanilla extract'}), frozenset({'sugar', 'baking powder'}), frozenset({'sugar', 'lemon juice'}), frozenset({'egg', 'water'}), frozenset({'salt', 'lemon juice'}), frozenset({'black pepper', 'garlic'}), frozenset({'onion', 'water'}), frozenset({'sugar', 'milk'}), frozenset({'salt', 'milk'}), frozenset({'unsalted butter', 'baking powder'}), frozenset({'egg', 'all purpose flour'}), frozenset({'water', 'olive oil'}), frozenset({'salt', 'all purpose flour'}), frozenset({'garlic clove', 'olive oil'}), frozenset({'water', 'garlic'}), frozenset({'egg', 'baking soda'}), frozenset({'carrot', 'onion'}), frozenset({'salt', 'baking soda'}), frozenset({'sugar', 'cinnamon'}), frozenset({'egg', 'cinnamon'}), frozenset({'chicken broth', 'onion'}), frozenset({'unsalted butter', 'all purpose flour'}), frozenset({'salt', 'unsalte butter'}), frozenset({'lemon juice', 'garlic'}), frozenset({'tomato', 'olive oil'}), frozenset({'salt', 'cinnamon'}), frozenset({'sugar', 'all purpose flour'}), frozenset({'unsalted butter', 'water'}), frozenset({'shallot', 'olive oil'}), frozenset({'egg', 'unsalte butter'}), frozenset({'egg', 'olive oil'}), frozenset({'egg', 'lemon juice'}), frozenset({'salt', 'vegetable oil'}), frozenset({'onion', 'black pepper'}), frozenset({'thyme', 'olive oil'}), frozenset({'onion', 'thyme'}), frozenset({'garlic', 'vegetable oil'}), frozenset({'parsley', 'olive oil'}), frozenset({'thyme', 'garlic'}), frozenset({'tomato', 'garlic'}), frozenset({'unsalted butter', 'milk'}), frozenset({'chicken broth', 'olive oil'}), frozenset({'unsalted butter', 'cinnamon'}), frozenset({'all - purpose flour', 'baking powder'}), frozenset({'sugar', 'unsalte butter'}), frozenset({'sugar', 'baking soda'}), frozenset({'egg', 'heavy cream'}), frozenset({'carrot', 'garlic'}), frozenset({'sugar', 'ginger'}), frozenset({'onion', 'vegetable oil'}), frozenset({'egg', 'onion'}), frozenset({'chicken broth', 'garlic'}), frozenset({'garlic', 'parsley'}), frozenset({'garlic', 'ginger'}), frozenset({'sugar', 'heavy cream'}), frozenset({'unsalted butter', 'lemon juice'}), frozenset({'tomato', 'onion'}), frozenset({'unsalted butter', 'baking soda'}), frozenset({'vanilla extract', 'baking powder'}), frozenset({'red onion', 'olive oil'}), frozenset({'lemon juice', 'water'}), frozenset({'egg', 'garlic'}), frozenset({'egg', 'black pepper'}), frozenset({'shallot', 'garlic'}), frozenset({'salt', 'ginger'}), frozenset({'baking soda', 'baking powder'}), frozenset({'dry white wine', 'olive oil'}), frozenset({'carrot', 'olive oil'}), frozenset({'sugar', 'whip cream'}), frozenset({'egg', 'vegetable oil'}), frozenset({'sugar', 'garlic'}), frozenset({'sugar', 'vegetable oil'}), frozenset({'onion', 'parsley'}), frozenset({'egg', 'whip cream'}), frozenset({'onion', 'celery'}), frozenset({'egg', 'butter'}), frozenset({'milk', 'all - purpose flour'}), frozenset({'sugar', 'olive oil'}), frozenset({'red bell pepper', 'olive oil'}), frozenset({'rosemary', 'olive oil'}), frozenset({' ...
# [frozenset({'salt', 'sugar', 'egg'}), frozenset({'salt', 'unsalted butter', 'egg'}), frozenset({'sugar', 'unsalted butter', 'egg'}), frozenset({'salt', 'unsalted butter', 'sugar'}), frozenset({'sugar', 'egg', 'vanilla extract'}), frozenset({'salt', 'egg', 'all - purpose flour'}), frozenset({'salt', 'egg', 'baking powder'}), frozenset({'onion', 'garlic', 'olive oil'}), frozenset({'egg', 'unsalted butter', 'vanilla extract'}), frozenset({'sugar', 'egg', 'baking powder'}), frozenset({'salt', 'egg', 'vanilla extract'}), frozenset({'salt', 'unsalted butter', 'all - purpose flour'}), frozenset({'sugar', 'egg', 'all - purpose flour'}), frozenset({'egg', 'unsalted butter', 'all - purpose flour'}), frozenset({'salt', 'sugar', 'baking powder'}), frozenset({'sugar', 'unsalted butter', 'vanilla extract'}), frozenset({'salt', 'sugar', 'all - purpose flour'}), frozenset({'egg', 'unsalted butter', 'baking powder'}), frozenset({'sugar', 'egg', 'milk'}), frozenset({'salt', 'sugar', 'vanilla extract'}), frozenset({'salt', 'unsalted butter', 'baking powder'}), frozenset({'salt', 'baking soda', 'egg'}), frozenset({'salt', 'black pepper', 'olive oil'}), frozenset({'salt', 'egg', 'milk'}), frozenset({'salt', 'unsalted butter', 'vanilla extract'}), frozenset({'salt', 'garlic', 'olive oil'}), frozenset({'salt', 'egg', 'all purpose flour'}), frozenset({'sugar', 'unsalted butter', 'all - purpose flour'}), frozenset({'sugar', 'unsalted butter', 'baking powder'}), frozenset({'sugar', 'egg', 'all purpose flour'}), frozenset({'salt', 'garlic', 'black pepper'}), frozenset({'sugar', 'unsalted butter', 'all purpose flour'}), frozenset({'egg', 'unsalted butter', 'all purpose flour'}), frozenset({'sugar', 'egg', 'water'}), frozenset({'salt', 'unsalted butter', 'all purpose flour'}), frozenset({'salt', 'sugar', 'all purpose flour'}), frozenset({'sugar', 'baking soda', 'egg'}), frozenset({'egg', 'vanilla extract', 'baking powder'}), frozenset({'salt', 'egg', 'water'}), frozenset({'sugar', 'egg', 'cinnamon'}), frozenset({'salt', 'egg', 'cinnamon'}), frozenset({'egg', 'all - purpose flour', 'baking powder'}), frozenset({'salt', 'sugar', 'water'}), frozenset({'salt', 'baking soda', 'sugar'}), frozenset({'salt', 'onion', 'black pepper'}), frozenset({'salt', 'all - purpose flour', 'baking powder'}), frozenset({'egg', 'unsalted butter', 'baking soda'}), frozenset({'egg', 'unsalted butter', 'milk'}), frozenset({'lemon juice', 'garlic', 'olive oil'}), frozenset({'salt', 'onion', 'garlic'}), frozenset({'salt', 'unsalted butter', 'baking soda'}), frozenset({'egg', 'baking soda', 'baking powder'}), frozenset({'salt', 'sugar', 'milk'}), frozenset({'salt', 'baking soda', 'baking powder'}), frozenset({'salt', 'sugar', 'cinnamon'}), frozenset({'salt', 'unsalted butter', 'water'}), frozenset({'black pepper', 'garlic', 'olive oil'}), frozenset({'salt', 'vanilla extract', 'baking powder'}), frozenset({'salt', 'onion', 'olive oil'}), frozenset({'egg', 'unsalted butter', 'cinnamon'}), frozenset({'salt', 'unsalte butter', 'egg'}), frozenset({'sugar', 'unsalte butter', 'egg'}), frozenset({'sugar', 'unsalted butter', 'cinnamon'}), frozenset({'salt', 'unsalted butter', 'milk'}), frozenset({'sugar', 'vanilla extract', 'baking powder'}), frozenset({'salt', 'unsalted butter', 'cinnamon'}), frozenset({'sugar', 'all - purpose flour', 'baking powder'}), frozenset({'tomato', 'garlic', 'olive oil'}), frozenset({'salt', 'egg', 'black pepper'}), frozenset({'egg', 'unsalted butter', 'water'}), frozenset({'carrot', 'onion', 'garlic'}), frozenset({'sugar', 'egg', 'heavy cream'}), frozenset({'sugar', 'unsalted butter', 'baking soda'}), frozenset({'egg', 'baking soda', 'all - purpose flour'}), frozenset({'salt', 'baking soda', 'all - purpose flour'}), frozenset({'egg', 'vanilla extract', 'all purpose flour'}), frozenset({'unsalted butter', 'vanilla extract', 'baking powder'}), frozenset({'egg', 'baking soda', 'vanilla extract'}), frozenset({'sugar', 'lemon juice', 'egg'}), frozenset({'parsley', 'garli ...
# [frozenset({'egg', 'salt', 'unsalted butter', 'sugar'}), frozenset({'egg', 'salt', 'sugar', 'baking powder'}), frozenset({'egg', 'sugar', 'unsalted butter', 'vanilla extract'}), frozenset({'egg', 'salt', 'sugar', 'vanilla extract'}), frozenset({'egg', 'salt', 'unsalted butter', 'all - purpose flour'}), frozenset({'egg', 'salt', 'unsalted butter', 'baking powder'}), frozenset({'egg', 'salt', 'sugar', 'all - purpose flour'}), frozenset({'egg', 'salt', 'unsalted butter', 'vanilla extract'}), frozenset({'egg', 'sugar', 'unsalted butter', 'baking powder'}), frozenset({'salt', 'unsalted butter', 'sugar', 'vanilla extract'}), frozenset({'salt', 'unsalted butter', 'sugar', 'baking powder'}), frozenset({'egg', 'sugar', 'unsalted butter', 'all - purpose flour'}), frozenset({'salt', 'unsalted butter', 'sugar', 'all - purpose flour'}), frozenset({'baking soda', 'egg', 'salt', 'sugar'}), frozenset({'baking soda', 'egg', 'salt', 'unsalted butter'}), frozenset({'egg', 'sugar', 'unsalted butter', 'all purpose flour'}), frozenset({'egg', 'salt', 'all - purpose flour', 'baking powder'}), frozenset({'egg', 'salt', 'vanilla extract', 'baking powder'}), frozenset({'salt', 'unsalted butter', 'sugar', 'all purpose flour'}), frozenset({'egg', 'salt', 'unsalted butter', 'all purpose flour'}), frozenset({'egg', 'milk', 'salt', 'sugar'}), frozenset({'egg', 'sugar', 'vanilla extract', 'baking powder'}), frozenset({'egg', 'salt', 'sugar', 'all purpose flour'}), frozenset({'baking soda', 'egg', 'salt', 'baking powder'}), frozenset({'egg', 'sugar', 'all - purpose flour', 'baking powder'}), frozenset({'egg', 'salt', 'sugar', 'cinnamon'}), frozenset({'egg', 'milk', 'salt', 'unsalted butter'}), frozenset({'egg', 'unsalted butter', 'vanilla extract', 'baking powder'}), frozenset({'baking soda', 'egg', 'sugar', 'unsalted butter'}), frozenset({'salt', 'sugar', 'all - purpose flour', 'baking powder'}), frozenset({'salt', 'sugar', 'vanilla extract', 'baking powder'}), frozenset({'egg', 'milk', 'sugar', 'unsalted butter'}), frozenset({'baking soda', 'egg', 'salt', 'all - purpose flour'}), frozenset({'baking soda', 'salt', 'unsalted butter', 'sugar'}), frozenset({'egg', 'salt', 'unsalted butter', 'cinnamon'}), frozenset({'baking soda', 'egg', 'sugar', 'baking powder'}), frozenset({'black pepper', 'olive oil', 'salt', 'garlic'}), frozenset({'egg', 'sugar', 'unsalted butter', 'cinnamon'}), frozenset({'salt', 'unsalted butter', 'all - purpose flour', 'baking powder'}), frozenset({'salt', 'unsalted butter', 'vanilla extract', 'baking powder'}), frozenset({'egg', 'unsalted butter', 'all - purpose flour', 'baking powder'}), frozenset({'baking soda', 'egg', 'salt', 'vanilla extract'}), frozenset({'egg', 'sugar', 'vanilla extract', 'all purpose flour'}), frozenset({'egg', 'unsalted butter', 'vanilla extract', 'all purpose flour'}), frozenset({'egg', 'salt', 'sugar', 'water'}), frozenset({'baking soda', 'salt', 'sugar', 'baking powder'}), frozenset({'sugar', 'unsalted butter', 'vanilla extract', 'baking powder'}), frozenset({'salt', 'unsalted butter', 'sugar', 'cinnamon'})]
# [frozenset({'salt', 'unsalted butter', 'egg', 'sugar', 'vanilla extract'}), frozenset({'salt', 'unsalted butter', 'egg', 'sugar', 'baking powder'}), frozenset({'salt', 'unsalted butter', 'egg', 'sugar', 'all - purpose flour'}), frozenset({'salt', 'egg', 'sugar', 'vanilla extract', 'baking powder'}), frozenset({'salt', 'unsalted butter', 'egg', 'sugar', 'all purpose flour'}), frozenset({'salt', 'egg', 'sugar', 'all - purpose flour', 'baking powder'})]
# []

# %%
dfs = []
for f in f_sets:
    freq_vec = []
    for s in f:
        insert = list(s)
        insert.sort()
        freq_vec.append(insert)
    new_df = pd.DataFrame(freq_vec, columns=["Item {}".format(x) for x in range(1, len(insert) + 1)])
    dfs.append(new_df)

# %%
dfs[0].head(10)
# Out:
#          Item 1           Item 2
# 0           egg             salt
# 1           egg            sugar
# 2        garlic        olive oil
# 3          salt            sugar
# 4           egg  unsalted butter
# 5          salt  unsalted butter
# 6         sugar  unsalted butter
# 7        garlic            onion
# 8     olive oil            onion
# 9  black pepper             salt

# %%
dfs[1].head(10)
# Out:
#                 Item 1           Item 2           Item 3
# 0                  egg             salt            sugar
# 1                  egg             salt  unsalted butter
# 2                  egg            sugar  unsalted butter
# 3                 salt            sugar  unsalted butter
# 4                  egg            sugar  vanilla extract
# 5  all - purpose flour              egg             salt
# 6        baking powder              egg             salt
# 7               garlic        olive oil            onion
# 8                  egg  unsalted butter  vanilla extract
# 9        baking powder              egg            sugar

# %%
dfs[2].head(10)
# Out:
#                 Item 1 Item 2           Item 3           Item 4
# 0                  egg   salt            sugar  unsalted butter
# 1        baking powder    egg             salt            sugar
# 2                  egg  sugar  unsalted butter  vanilla extract
# 3                  egg   salt            sugar  vanilla extract
# 4  all - purpose flour    egg             salt  unsalted butter
# 5        baking powder    egg             salt  unsalted butter
# 6  all - purpose flour    egg             salt            sugar
# 7                  egg   salt  unsalted butter  vanilla extract
# 8        baking powder    egg            sugar  unsalted butter
# 9                 salt  sugar  unsalted butter  vanilla extract

# %%
dfs[3].head(10)
# Out:
#                 Item 1         Item 2 Item 3           Item 4           Item 5
# 0                  egg           salt  sugar  unsalted butter  vanilla extract
# 1        baking powder            egg   salt            sugar  unsalted butter
# 2  all - purpose flour            egg   salt            sugar  unsalted butter
# 3        baking powder            egg   salt            sugar  vanilla extract
# 4    all purpose flour            egg   salt            sugar  unsalted butter
# 5  all - purpose flour  baking powder    egg             salt            sugar
