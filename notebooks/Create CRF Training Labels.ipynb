# %%
from decimal import Decimal, InvalidOperation
import spacy
import pandas as pd

# %%
nlp = spacy.load("en_core_web_lg", disable=["tagger", "parser", "ner", "textcat"])

# %%
def match_up(df):
    """
    Returns our best guess of the match between the tags and the
    words from the display text.
    This problem is difficult for the following reasons:
        * not all the words in the display name have associated tags
        * the quantity field is stored as a number, but it appears
          as a string in the display name
        * the comment is often a compilation of different comments in
          the display name
    """
    labels = []
    name = df["name"].split()
    unit = df["unit"]
    qty = df["qty"]

    for token in df["input"]:
        decimal_token = None
        try:
            decimal_token = float(token)
        except ValueError:
            pass
        if token in list(name):
            labels.append("NAME")
            name.remove(token)
        elif token == unit:
            labels.append("UNIT")
            unit = ""
        elif decimal_token is not None and decimal_token == qty:
            labels.append("QTY")
            qty = float('nan')
        #elif token in list(comment):
        #    labels.append("COMMENT")
        #    comment.remove(token)
        else:
            labels.append("COMMENT")
    return labels

def add_prefixes(data):
    """
    We use BIO tagging/chunking to differentiate between tags
    at the start of a tag sequence and those in the middle. This
    is a common technique in entity recognition.

    Reference: http://www.kdd.cis.ksu.edu/Courses/Spring-2013/CIS798/Handouts/04-ramshaw95text.pdf
    """
    prev_tag = None
    new_data = []

    for token, tag in data:

        new_tag = ""

        p = "B" if ((prev_tag is None) or (tag != prev_tag)) else "I"
        new_tag = "%s-%s" % (p, tag)
        new_data.append(new_tag)
        prev_tag = tag

    return new_data

# %%
# Load raw data and do some preprocessing
training_data = pd.read_pickle("../data/interim/crf_data.pickle")
#test_data = pd.read_pickle("../data/interim/crf_test_data.pickle")

# %%
training_data.head(25)
# Out:
#                                                    input  \
# index
# 0      1.25 cups cooked and pureed fresh butternut sq...
# 1      1 cup peeled and cooked fresh chestnuts (about...
# 2                1 medium size onion, peeled and chopped
# 3                        2 stalks celery, chopped coarse
# 4                          1.5 tablespoons vegetable oil
# 6      2 tablespoons unflavored gelatin, dissolved in...
# 7                                                   Salt
# 8                  1 cup canned plum tomatoes with juice
# 9                              6 cups veal or beef stock
# 10                         0.33 cup Worcestershire sauce
# 11                      1 tablespoon Louisiana hot sauce
# 12                    0.5 teaspoon hot red pepper flakes
# 13                                          4 bay leaves
# 14                  6 cloves garlic, crushed and chopped
# 15                           2 carrots, peeled and diced
# 16                                2 medium onions, diced
# 17                                  6 tablespoons butter
# 18     1 tablespoon Creole seasoning, or other season...
# 19                                 3 pounds beef brisket
# 20                         0.5 cup fine dry bread crumbs
# 21                           Freshly ground black pepper
# 22                           12 oysters and their liquor
# 23                        3 tablespoons minced scallions
# 24                                    1 tablespoon flour
# 25     6 ounces button mushrooms, thinly sliced then ...
#
#                           name   qty        unit
# index
# 0             butternut squash  1.25         cup
# 1                     chestnut     1         cup
# 2                        onion     1
# 3                       celery     2       stalk
# 4                vegetable oil   1.5  tablespoon
# 6                      gelatin     2  tablespoon
# 7                         Salt   NaN
# 8                  plum tomato     1         cup
# 9                   veal stock     6         cup
# 10        Worcestershire sauce  0.33         cup
# 11         Louisiana hot sauce     1  tablespoon
# 12        hot red pepper flake   0.5    teaspoon
# 13                         bay     4       leave
# 14                      garlic     6      cleave
# 15                      carrot     2
# 16                       onion     2
# 17                      butter     6  tablespoon
# 18               Creole season     1  tablespoon
# 19                beef brisket     3       pound
# 20                 bread crumb   0.5         cup
# 21                black pepper   NaN
# 22     oyster and their liquor    12
# 23                    scallion     3  tablespoon
# 24                       flour     1  tablespoon
# 25             button mushroom     6       ounce

# %%
# have spacy parse the input string with the full pipeline to generate features this will take some time
training_data["input"] = list(
    nlp.pipe(training_data["input"].astype("unicode").values, batch_size=50)
)

#test_data["input"] = list(
#    nlp.pipe(test_data["input"].astype("unicode").values, batch_size=50)
#)

# %%
training_data.head(25)
# Out:
#                                                    input  \
# index
# 0      (1.25, cups, cooked, and, pureed, fresh, butte...
# 1      (1, cup, peeled, and, cooked, fresh, chestnuts...
# 2      (1, medium, size, onion, ,, peeled, and, chopped)
# 3                (2, stalks, celery, ,, chopped, coarse)
# 4                     (1.5, tablespoons, vegetable, oil)
# 6      (2, tablespoons, unflavored, gelatin, ,, disso...
# 7                                                 (Salt)
# 8          (1, cup, canned, plum, tomatoes, with, juice)
# 9                       (6, cups, veal, or, beef, stock)
# 10                    (0.33, cup, Worcestershire, sauce)
# 11                (1, tablespoon, Louisiana, hot, sauce)
# 12             (0.5, teaspoon, hot, red, pepper, flakes)
# 13                                      (4, bay, leaves)
# 14         (6, cloves, garlic, ,, crushed, and, chopped)
# 15                   (2, carrots, ,, peeled, and, diced)
# 16                         (2, medium, onions, ,, diced)
# 17                              (6, tablespoons, butter)
# 18     (1, tablespoon, Creole, seasoning, ,, or, othe...
# 19                            (3, pounds, beef, brisket)
# 20                  (0.5, cup, fine, dry, bread, crumbs)
# 21                      (Freshly, ground, black, pepper)
# 22                     (12, oysters, and, their, liquor)
# 23                   (3, tablespoons, minced, scallions)
# 24                                (1, tablespoon, flour)
# 25     (6, ounces, button, mushrooms, ,, thinly, slic...
#
#                           name   qty        unit
# index
# 0             butternut squash  1.25         cup
# 1                     chestnut     1         cup
# 2                        onion     1
# 3                       celery     2       stalk
# 4                vegetable oil   1.5  tablespoon
# 6                      gelatin     2  tablespoon
# 7                         Salt   NaN
# 8                  plum tomato     1         cup
# 9                   veal stock     6         cup
# 10        Worcestershire sauce  0.33         cup
# 11         Louisiana hot sauce     1  tablespoon
# 12        hot red pepper flake   0.5    teaspoon
# 13                         bay     4       leave
# 14                      garlic     6      cleave
# 15                      carrot     2
# 16                       onion     2
# 17                      butter     6  tablespoon
# 18               Creole season     1  tablespoon
# 19                beef brisket     3       pound
# 20                 bread crumb   0.5         cup
# 21                black pepper   NaN
# 22     oyster and their liquor    12
# 23                    scallion     3  tablespoon
# 24                       flour     1  tablespoon
# 25             button mushroom     6       ounce

# %%
# for assigining labels we only need lemmas
"""training_data["name"] = list(
    nlp.pipe(training_data["name"].astype("unicode").values, batch_size=50)
)
training_data["unit"] = list(
    nlp.pipe(training_data["unit"].astype("unicode").values, batch_size=50)
)
training_data["comment"] = list(
    nlp.pipe(training_data["comment"].astype("unicode").values, batch_size=50)
)"""

"""test_data["name"] = list(
    nlp.pipe(test_data["name"].astype("unicode").values, batch_size=50)
)
test_data["unit"] = list(
    nlp.pipe(test_data["unit"].astype("unicode").values, batch_size=50)
)
test_data["comment"] = list(
    nlp.pipe(test_data["comment"].astype("unicode").values, batch_size=50)
)"""
# Out:
# 'test_data["name"] = list(\n    nlp.pipe(test_data["name"].astype("unicode").values, batch_size=50)\n)\ntest_data["unit"] = list(\n    nlp.pipe(test_data["unit"].astype("unicode").values, batch_size=50)\n)\ntest_data["comment"] = list(\n    nlp.pipe(test_data["comment"].astype("unicode").values, batch_size=50)\n)'

# %%
#training_data.head()

# %%
training_data["input"] = training_data["input"].apply(
    lambda doc: [token.lemma_ for token in doc]
)
"""training_data["name"] = training_data["name"].apply(
    lambda doc: [token.lemma_ for token in doc]
)
training_data["unit"] = training_data["unit"].apply(
    lambda doc: [token.lemma_ for token in doc]
)
training_data["comment"] = training_data["comment"].apply(
    lambda doc: [token.lemma_ for token in doc]
)"""

"""test_data["input"] = test_data["input"].apply(
    lambda doc: [token.lemma_ for token in doc]
)
test_data["name"] = test_data["name"].apply(
    lambda doc: [token.lemma_ for token in doc]
)
test_data["unit"] = test_data["unit"].apply(
    lambda doc: [token.lemma_ for token in doc]
)
test_data["comment"] = test_data["comment"].apply(
    lambda doc: [token.lemma_ for token in doc]
)"""
# Out:
# 'test_data["input"] = test_data["input"].apply(\n    lambda doc: [token.lemma_ for token in doc]\n)\ntest_data["name"] = test_data["name"].apply(\n    lambda doc: [token.lemma_ for token in doc]\n)\ntest_data["unit"] = test_data["unit"].apply(\n    lambda doc: [token.lemma_ for token in doc]\n)\ntest_data["comment"] = test_data["comment"].apply(\n    lambda doc: [token.lemma_ for token in doc]\n)'

# %%
training_data.head(25)
# Out:
#                                                    input  \
# index
# 0      [1.25, cup, cook, and, puree, fresh, butternut...
# 1      [1, cup, peel, and, cook, fresh, chestnut, (, ...
# 2           [1, medium, size, onion, ,, peel, and, chop]
# 3                    [2, stalk, celery, ,, chop, coarse]
# 4                      [1.5, tablespoon, vegetable, oil]
# 6      [2, tablespoon, unflavored, gelatin, ,, dissol...
# 7                                                 [Salt]
# 8               [1, cup, can, plum, tomato, with, juice]
# 9                        [6, cup, veal, or, beef, stock]
# 10                    [0.33, cup, Worcestershire, sauce]
# 11                [1, tablespoon, Louisiana, hot, sauce]
# 12              [0.5, teaspoon, hot, red, pepper, flake]
# 13                                       [4, bay, leave]
# 14               [6, clove, garlic, ,, crush, and, chop]
# 15                       [2, carrot, ,, peel, and, dice]
# 16                           [2, medium, onion, ,, dice]
# 17                               [6, tablespoon, butter]
# 18     [1, tablespoon, Creole, season, ,, or, other, ...
# 19                             [3, pound, beef, brisket]
# 20                   [0.5, cup, fine, dry, bread, crumb]
# 21                       [Freshly, grind, black, pepper]
# 22                      [12, oyster, and, their, liquor]
# 23                      [3, tablespoon, mince, scallion]
# 24                                [1, tablespoon, flour]
# 25     [6, ounce, button, mushroom, ,, thinly, slice,...
#
#                           name   qty        unit
# index
# 0             butternut squash  1.25         cup
# 1                     chestnut     1         cup
# 2                        onion     1
# 3                       celery     2       stalk
# 4                vegetable oil   1.5  tablespoon
# 6                      gelatin     2  tablespoon
# 7                         Salt   NaN
# 8                  plum tomato     1         cup
# 9                   veal stock     6         cup
# 10        Worcestershire sauce  0.33         cup
# 11         Louisiana hot sauce     1  tablespoon
# 12        hot red pepper flake   0.5    teaspoon
# 13                         bay     4       leave
# 14                      garlic     6      cleave
# 15                      carrot     2
# 16                       onion     2
# 17                      butter     6  tablespoon
# 18               Creole season     1  tablespoon
# 19                beef brisket     3       pound
# 20                 bread crumb   0.5         cup
# 21                black pepper   NaN
# 22     oyster and their liquor    12
# 23                    scallion     3  tablespoon
# 24                       flour     1  tablespoon
# 25             button mushroom     6       ounce

# %%
training_data["labels"] = training_data.apply(match_up, axis=1)
#match_up(training_data.iloc[0])
#test_data["labels"] = test_data.apply(match_up, axis=1)

# %%
training_data[training_data.labels.apply(lambda x: 'OTHER' in x)]
# Out:
# Empty DataFrame
# Columns: [input, name, qty, unit, labels]
# Index: []

# %%
training_data.iloc[25:50]
# Out:
#                                                    input  \
# index
# 26                              [13, tablespoon, butter]
# 27                        [4, large, artichoke, ,, trim]
# 28                                 [Juice, of, 1, lemon]
# 29                                                [Salt]
# 30                             [Confectioners, ', sugar]
# 31                    [0.25, teaspoon, vanilla, extract]
# 32                                       [2, large, egg]
# 33                   [Pinch, of, freshly, grate, nutmeg]
# 34                           [2, teaspoon, bake, powder]
# 35                                [0.25, teaspoon, salt]
# 36                                    [0.25, cup, sugar]
# 37                                [6, tablespoon, flour]
# 38     [2, cup, cook, medium,  , or, long, grain, whi...
# 39                   [Vegetable, oil, ,, for, deep, fry]
# 40                              [pound, elbow, macaroni]
# 41                       [Freshly, grind, black, pepper]
# 42                         [2, teaspoon, Dijon, mustard]
# 43                                   [cup, heavy, cream]
# 44                                 [2, cup, whole, milk]
# 45              [0.5, teaspoon, hot, red, pepper, flake]
# 46                                [3, tablespoon, flour]
# 47        [5, cup, coarse, grate, extra, sharp, Cheddar]
# 48        [2, cup, panko, or, coarse, dry, bread, crumb]
# 49                     [5, tablespoon, unsalted, butter]
# 50                                                [Salt]
#
#                         name   qty        unit  \
# index
# 26                    butter    13  tablespoon
# 27                 artichoke     4
# 28               lemon Juice     1
# 29                      Salt   NaN
# 30     Confectioners ' sugar   NaN
# 31           vanilla extract  0.25    teaspoon
# 32                       egg     2
# 33                    nutmeg     1       pinch
# 34               bake powder     2    teaspoon
# 35                      salt  0.25    teaspoon
# 36                     sugar  0.25         cup
# 37                     flour     6  tablespoon
# 38                white rice     2         cup
# 39             Vegetable oil   NaN
# 40            elbow macaroni   NaN       pound
# 41              black pepper   NaN
# 42             Dijon mustard     2    teaspoon
# 43               heavy cream   NaN         cup
# 44                      milk     2         cup
# 45      hot red pepper flake   0.5    teaspoon
# 46                     flour     3  tablespoon
# 47                   Cheddar     5         cup
# 48               bread crumb     2         cup
# 49           unsalted butter     5  tablespoon
# 50                      Salt   NaN
#
#                                                   labels
# index
# 26                                     [QTY, UNIT, NAME]
# 27                [QTY, COMMENT, NAME, COMMENT, COMMENT]
# 28                            [NAME, COMMENT, QTY, NAME]
# 29                                                [NAME]
# 30                                    [NAME, NAME, NAME]
# 31                               [QTY, UNIT, NAME, NAME]
# 32                                  [QTY, COMMENT, NAME]
# 33            [COMMENT, COMMENT, COMMENT, COMMENT, NAME]
# 34                               [QTY, UNIT, NAME, NAME]
# 35                                     [QTY, UNIT, NAME]
# 36                                     [QTY, UNIT, NAME]
# 37                                     [QTY, UNIT, NAME]
# 38     [QTY, UNIT, COMMENT, COMMENT, COMMENT, COMMENT...
# 39      [NAME, NAME, COMMENT, COMMENT, COMMENT, COMMENT]
# 40                                    [UNIT, NAME, NAME]
# 41                        [COMMENT, COMMENT, NAME, NAME]
# 42                               [QTY, UNIT, NAME, NAME]
# 43                                    [UNIT, NAME, NAME]
# 44                            [QTY, UNIT, COMMENT, NAME]
# 45                   [QTY, UNIT, NAME, NAME, NAME, NAME]
# 46                                     [QTY, UNIT, NAME]
# 47     [QTY, UNIT, COMMENT, COMMENT, COMMENT, COMMENT...
# 48     [QTY, UNIT, COMMENT, COMMENT, COMMENT, COMMENT...
# 49                               [QTY, UNIT, NAME, NAME]
# 50                                                [NAME]

# %%
crf_training_labels = pd.Series(
    training_data.apply(
        lambda row: add_prefixes(zip(row["input"], row["labels"])), axis=1
    )
)
#crf_test_labels = pd.Series(
#    test_data.apply(
#        lambda row: add_prefixes(zip(row["input"], row["labels"])), axis=1
#    )
#)

# %%
crf_training_labels.head(25)
# Out:
# index
# 0     [B-QTY, B-UNIT, B-COMMENT, I-COMMENT, I-COMMEN...
# 1     [B-QTY, B-UNIT, B-COMMENT, I-COMMENT, I-COMMEN...
# 2     [B-QTY, B-COMMENT, I-COMMENT, B-NAME, B-COMMEN...
# 3     [B-QTY, B-UNIT, B-NAME, B-COMMENT, I-COMMENT, ...
# 4                       [B-QTY, B-UNIT, B-NAME, I-NAME]
# 6     [B-QTY, B-UNIT, B-COMMENT, B-NAME, B-COMMENT, ...
# 7                                              [B-NAME]
# 8     [B-QTY, B-UNIT, B-COMMENT, B-NAME, I-NAME, B-C...
# 9     [B-QTY, B-UNIT, B-NAME, B-COMMENT, I-COMMENT, ...
# 10                      [B-QTY, B-UNIT, B-NAME, I-NAME]
# 11              [B-QTY, B-UNIT, B-NAME, I-NAME, I-NAME]
# 12      [B-QTY, B-UNIT, B-NAME, I-NAME, I-NAME, I-NAME]
# 13                              [B-QTY, B-NAME, B-UNIT]
# 14    [B-QTY, B-COMMENT, B-NAME, B-COMMENT, I-COMMEN...
# 15    [B-QTY, B-NAME, B-COMMENT, I-COMMENT, I-COMMEN...
# 16     [B-QTY, B-COMMENT, B-NAME, B-COMMENT, I-COMMENT]
# 17                              [B-QTY, B-UNIT, B-NAME]
# 18    [B-QTY, B-UNIT, B-NAME, I-NAME, B-COMMENT, I-C...
# 19                      [B-QTY, B-UNIT, B-NAME, I-NAME]
# 20    [B-QTY, B-UNIT, B-COMMENT, I-COMMENT, B-NAME, ...
# 21               [B-COMMENT, I-COMMENT, B-NAME, I-NAME]
# 22              [B-QTY, B-NAME, I-NAME, I-NAME, I-NAME]
# 23                   [B-QTY, B-UNIT, B-COMMENT, B-NAME]
# 24                              [B-QTY, B-UNIT, B-NAME]
# 25    [B-QTY, B-UNIT, B-NAME, I-NAME, B-COMMENT, I-C...
# dtype: object

# %%
crf_training_labels.to_pickle("../data/interim/crf_training_labels.pickle")
#crf_test_labels.to_pickle("../data/interim/crf_test_labels.pickle")
